# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # Importing the data

# %%
startups_data = pd.read_csv(r"C:\Users\Dawood MD\Downloads\50_Startups (1).csv")
startups_data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # Performing Explorartory Data Analysis (EDA)

# %%
startups_data.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# defining the data type and structure
startups_data.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
type(startups_data)
# Out:
# pandas.core.frame.DataFrame

# %%
startups_data.shape
# Out:
# (50, 5)

# %%
#Data type conversion
startups_data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data = startups_data.copy()

# %%
startups_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#count of the duplicates
data[data.duplicated()].shape
# Out:
# (0, 5)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#outliers detections
data['R&D Spend'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['R&D Spend'])
# Out:
# <Axes: >

# %%
data['Administration'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='Administration')
# Out:
# <Axes: >

# %%
data['Marketing Spend'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['Marketing Spend'])
# Out:
# <Axes: >

# %%
data['State'].hist()
# Out:
# <Axes: >

# %%
data['Profit'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['Profit'])
# Out:
# <Axes: >

# %%
data['State'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
data[data.isnull().any(axis=1)].head(10)
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
obj_column = data[['State']]

# %%
obj_column.isnull().sum()
# Out:
# State    0
# dtype: int64

# %%
# Scatter plot and Correlation analysis
# seaborn visualisation
import seaborn as sns
sns.pairplot(data)
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data1 = data.drop(columns=['State'])
data1.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
data2 = pd.get_dummies(data,columns=['State'])
data2
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83             False
# 1   162597.70       151377.59        443898.53  191792.06              True
# 2   153441.51       101145.55        407934.54  191050.39             False
# 3   144372.41       118671.85        383199.62  182901.99             False
# 4   142107.34        91391.77        366168.42  166187.94             False
# 5   131876.90        99814.71        362861.36  156991.12             False
# 6   134615.46       147198.87        127716.82  156122.51              True
# 7   130298.13       145530.06        323876.68  155752.60             False
# 8   120542.52       148718.95        311613.29  152211.77             False
# 9   123334.88       108679.17        304981.62  149759.96              True
# 10  101913.08       110594.11        229160.95  146121.95             False
# ...

# %%
df=
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data2 = data2.dropna()
data2
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83             False
# 1   162597.70       151377.59        443898.53  191792.06              True
# 2   153441.51       101145.55        407934.54  191050.39             False
# 3   144372.41       118671.85        383199.62  182901.99             False
# 4   142107.34        91391.77        366168.42  166187.94             False
# 5   131876.90        99814.71        362861.36  156991.12             False
# 6   134615.46       147198.87        127716.82  156122.51              True
# 7   130298.13       145530.06        323876.68  155752.60             False
# 8   120542.52       148718.95        311613.29  152211.77             False
# 9   123334.88       108679.17        304981.62  149759.96              True
# 10  101913.08       110594.11        229160.95  146121.95             False
# ...

# %%
#normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
ar = data.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledx = scaler.fit_transform(ar[:,0:3])

#transform the values
set_printoptions(precision=2)
print(rescaledx[0:3,:])
# Out:
# [[1.   0.65 1.  ]
#  [0.98 0.76 0.94]
#  [0.93 0.38 0.86]]

# %%
# standardize data (0 mean, 1 std)
from sklearn.preprocessing import StandardScaler

# %%
ar1 = data2.values

scaler1 = StandardScaler().fit(ar1)
rescaledx1= scaler1.transform(ar1)
#summary transform data
set_printoptions(precision=2)
print(rescaledx1[0:5,:])
# Out:
# [[ 2.02  0.56  2.15  2.01 -0.72 -0.69  1.39]
#  [ 1.96  1.08  1.92  2.    1.39 -0.69 -0.72]
#  [ 1.75 -0.73  1.63  1.98 -0.72  1.46 -0.72]
#  [ 1.55 -0.1   1.42  1.78 -0.72 -0.69  1.39]
#  [ 1.5  -1.08  1.28  1.36 -0.72  1.46 -0.72]]

# %%
# !pip install ydata_profiling
# !pip install sweetviz

# %%
import ydata_profiling as pp
import sweetviz as sv

# %%
data_report = pp.ProfileReport(data)
data_report.to_file(output_file='startups.html')
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
Sweet_report = sv.analyze(data)
Sweet_report.show_html("startups_data.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report startups_data.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Defining the X(independent) and Y(dependent) variable

# %%
df = pd.DataFrame(rescaledx1)
df.columns = ['R&D Spend','Administration','Marketing Spend','Profit','State_California','State_Florida','State_New York']
df= df[['R&D Spend','Administration','Marketing Spend','State_California','State_Florida','State_New York','Profit']]

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State_California  \
# 0    2.016411        0.560753         2.153943         -0.717741
# 1    1.955860        1.082807         1.923600          1.393261
# 2    1.754364       -0.728257         1.626528         -0.717741
# 3    1.554784       -0.096365         1.422210         -0.717741
# 4    1.504937       -1.079919         1.281528         -0.717741
# 5    1.279800       -0.776239         1.254210         -0.717741
# 6    1.340066        0.932147        -0.688150          1.393261
# 7    1.245057        0.871980         0.932186         -0.717741
# 8    1.030369        0.986952         0.830887         -0.717741
# 9    1.091819       -0.456640         0.776107          1.393261
# 10   0.620398       -0.387599         0.149807         -0.717741
# 11   0.593085       -1.065540         0.319834          1.393261
# 12   0.443260        0.215449         0.320617         -0.717741
# ...

# %%
x = df.drop(['Profit'],axis=1).values
y = df['Profit'].values

# %% [markdown]
# # Spliting the Data into Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=0)

# %% [markdown]
# # Predicting the Test set values

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([-0.19,  0.51,  0.55, -0.99,  1.7 ,  0.06, -1.14, -0.34,  0.06,
#         1.44, -0.39, -0.6 , -0.03, -0.54,  0.4 ])

# %% [markdown]
# # Prediction for whole data set

# %%
lr.predict([[2.016411,0.560753,2.153943,-0.717741,-0.685994,1.393261]])
# Out:
# array([2.01])

# %%
lr1 = LinearRegression()

# %%
lr1.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred1 = lr.predict(x)

# %%
y_pred1
# Out:
# array([ 2.01,  1.94,  1.7 ,  1.51,  1.44,  1.23,  1.13,  1.21,  1.01,
#         1.02,  0.55,  0.51,  0.42,  0.38,  0.96,  0.83,  0.1 ,  0.47,
#         0.4 ,  0.09,  0.09,  0.17,  0.06, -0.08, -0.03, -0.25, -0.03,
#         0.06, -0.19, -0.24, -0.35, -0.34, -0.35, -0.39, -0.54, -0.6 ,
#        -0.91, -0.68, -1.14, -0.78, -0.95, -0.99, -1.09, -1.31, -1.17,
#        -1.62, -1.39, -1.64, -1.69, -1.62])

# %%
lr1.score(x,y)
# Out:
# 0.9507524843355148

# %%
lr1.coef_
# Out:
# array([ 9.18e-01, -1.88e-02,  8.19e-02, -6.03e-04,  1.73e-03, -1.10e-03])

# %%
lr1.intercept_
# Out:
# -4.379835474499178e-16

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9358680970046517

# %%
lr.score(x_test,y_test)
# Out:
# 0.9358680970046517

# %% [markdown]
# # Ploting the results

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5,5))
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual Profit vs. Predected Profit')
# Out:
# Text(0.5, 1.0, 'Actual Profit vs. Predected Profit')

# %%
plt.figure(figsize=(5,5))
plt.scatter(y,y_pred1)
plt.xlabel('Actual Profit')
plt.ylabel('Predicted Profit')
plt.title('Actual Profit vs. Predected Profit')
# Out:
# Text(0.5, 1.0, 'Actual Profit vs. Predected Profit')

# %%
plt.hist(y_pred1-y)
# Out:
# (array([ 4.,  7.,  9., 14., 11.,  2.,  1.,  1.,  0.,  1.]),
#  array([-0.44, -0.32, -0.19, -0.06,  0.06,  0.19,  0.31,  0.44,  0.57,
#          0.69,  0.82]),
#  <BarContainer object of 10 artists>)

# %%
# Residuals Vs Fitted values
import matplotlib.pyplot as plt
plt.scatter(y_pred1,(y_pred1-y),c="r")
plt.hlines(y=0,xmin=0,xmax=1) 
# checking normal distribution for residual
plt.hist(y_pred1-y)
# Out:
# (array([ 4.,  7.,  9., 14., 11.,  2.,  1.,  1.,  0.,  1.]),
#  array([-0.44, -0.32, -0.19, -0.06,  0.06,  0.19,  0.31,  0.44,  0.57,
#          0.69,  0.82]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Defining the prdected values

# %%
y_pred_df= pd.DataFrame({'Actual Profit':y_test , 'Predicted profit':y_pred , 'Difference':y_test - y_pred})
y_pred_df
# Out:
#     Actual Profit  Predicted profit  Difference
# 0       -0.218798         -0.193726   -0.025072
# 1        0.808168          0.514378    0.293789
# 2        0.854847          0.548812    0.306034
# 3       -0.857466         -0.988140    0.130675
# 4        1.980842          1.701916    0.278926
# 5       -0.175542          0.063574   -0.239116
# 6       -0.771497         -1.142029    0.370532
# 7       -0.364127         -0.341035   -0.023092
# 8       -0.041613          0.062334   -0.103947
# 9        1.357740          1.437426   -0.079686
# 10      -0.381787         -0.388210    0.006423
# 11      -0.389291         -0.600785    0.211494
# 12      -0.157367         -0.026632   -0.130735
# 13      -0.383444         -0.541175    0.157730
# 14       0.307116          0.401188   -0.094072

# %%
y_pred1_df= pd.DataFrame({'Actual Profit':y , 'Predicted profit':y_pred1 , 'Difference':y - y_pred1})
y_pred1_df
# Out:
#     Actual Profit  Predicted profit  Difference
# 0        2.011203          2.010648    0.000555
# 1        1.999430          1.937757    0.061673
# 2        1.980842          1.701916    0.278926
# 3        1.776627          1.512238    0.264389
# 4        1.357740          1.437426   -0.079686
# 5        1.127250          1.234497   -0.107247
# 6        1.105481          1.134220   -0.028740
# 7        1.096210          1.211466   -0.115256
# 8        1.007470          1.007025    0.000445
# 9        0.946022          1.019274   -0.073252
# 10       0.854847          0.548812    0.306034
# 11       0.808168          0.514378    0.293789
# 12       0.741155          0.418006    0.323149
# 13       0.558750          0.377694    0.181055
# 14       0.516026          0.962208   -0.446182
# 15       0.448720          0.829238   -0.380519
# 16       0.375436          0.099187    0.276249
# 17       0.334771          0.468649   -0.133878
# 18       0.307116          0.401188   -0.094072
# ...
