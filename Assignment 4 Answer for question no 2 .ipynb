# %%
# !pip install ydata_profiling
# !pip install sweetviz

# %% [markdown]
# # Importing the Libraries

# %%
import pandas  as pd
import numpy as np
import ydata_profiling as pp
import sweetviz as sv

# %%
S_D = pd.read_csv("C:\Excelr assignments\Assigmnent 4 Simple Linear Regression\Salary_Data.csv")

# %%
S_D
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# # Determine the data structure and data type

# %%
S_D.shape
# Out:
# (30, 2)

# %%
S_D.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
type(S_D)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data Conversion

# %%
yrs_exp = S_D.iloc[0:30,0:1]

# %%
yrs_exp
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
salary = S_D.iloc[0:30,1:2]
salary
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
S_D.info
# Out:
# <bound method DataFrame.info of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %%
S_D.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# # Detection of outliers

# %%
import matplotlib.pyplot as mlt

# %%
mlt.boxplot(yrs_exp)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d67288dd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d72ad0350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d73864050>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d72ad54d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d72ad78d0>],
#  'means': []}

# %%
mlt.boxplot(salary)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d72d35f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d73239fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d731ba190>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d71c77210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d712533d0>],
#  'means': []}

# %% [markdown]
# # Heat map , Pairplot and correlation for sea born library

# %%
import seaborn as sns

# %%
sns.pairplot(S_D)
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(S_D,cmap="YlGnBu",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# sns.heatmap(S_D.corr(),cmap="YlGnBu",annot=True)

# %% [markdown]
# # Normalization of the data

# %%
from sklearn.preprocessing import MinMaxScaler
from numpy import set_printoptions

# %%
S_D1 = S_D.copy()

# %%
x=S_D['YearsExperience'].values 
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y=S_D['Salary'].values
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
x1=x.reshape((-1,1))

# %%
y1=y.reshape((-1,1))

# %%
EDA_report= pp.ProfileReport(S_D)
EDA_report.to_file(output_file='report.html')
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
EDA_report
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-02-05 14:26:31.827658&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
sweet_report = sv.analyze(S_D)
sweet_report.show_html('weather_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report weather_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from sklearn.linear_model import LinearRegression

# %%
mlt.scatter(S_D.YearsExperience,S_D.Salary)

# %%
mdl = LinearRegression()
mdl.fit(x1,y1)
pred = mdl.predict(x1)
#Adjusted R-squared value 
r_squared = mdl.score (x1,y1)
rmse1=np.sqrt(np.mean((pred-y1)**2))
m1 = mdl.coef_
c1 = mdl.intercept_

# %%
pred
# Out:
# array([[ 36187.15875227],
#        [ 38077.15121656],
#        [ 39967.14368085],
#        [ 44692.12484158],
#        [ 46582.11730587],
#        [ 53197.09093089],
#        [ 54142.08716303],
#        [ 56032.07962732],
#        [ 56032.07962732],
#        [ 60757.06078805],
#        [ 62647.05325234],
#        [ 63592.04948449],
#        [ 63592.04948449],
#        [ 64537.04571663],
#        [ 68317.03064522],
#        [ 72097.0155738 ],
#        [ 73987.00803809],
#        [ 75877.00050238],
#        [ 81546.97789525],
#        [ 82491.9741274 ],
#        [ 90051.94398456],
#        [ 92886.932681  ],
#        [100446.90253816],
#        [103281.8912346 ],
#        [108006.87239533],
#        [110841.86109176],
#        [115566.84225249],
#        [116511.83848464],
#        [123126.81210966],
#        [125016.80457395]])

# %%
r_squared
# Out:
# 0.9569566641435086

# %%
rmse1
# Out:
# 5592.043608760662

# %%
m1
# Out:
# array([[9449.96232146]])

# %%
c1
# Out:
# array([25792.20019867])

# %%
#### Residuals Vs Fitted values
mlt.scatter(pred,(pred-y1),c="r")
mlt.hlines(y=0,xmin=0,xmax=11)

# %%
mlt.hist(pred-y1)
# Out:
# (array([2., 2., 2., 1., 2., 6., 3., 4., 2., 6.]),
#  array([-11448.0258726 ,  -9507.42248153,  -7566.81909046,  -5626.21569939,
#          -3685.61230832,  -1745.00891726,    195.59447381,   2136.19786488,
#           4076.80125595,   6017.40464702,   7958.00803809]),
#  <BarContainer object of 10 artists>)

# %%
mlt.scatter(x1,y1)
mlt.plot(x1,pred,color= "red")
mlt.xlabel('Years Experience')
mlt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
