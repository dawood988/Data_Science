# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the Data set in Jupyter Notebook

# %%
data = pd.read_csv(r"C:\Excelr assignments\Assignment 6 Logistic regression\bank-full.csv")

# %%
data = data.sort_index()

# %%
data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # Performimg necessary Exploratory Data Analysis (EDA)

# %%
data.tail(10)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45201   53    management   married   tertiary      no      583      no   no
# 45202   34        admin.    single  secondary      no      557      no   no
# 45203   23       student    single   tertiary      no      113      no   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
data.shape
# Out:
# (45211, 17)

# %%
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Data conversion
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
data.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
data1 = data.copy()

# %%
data1
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # Creating dummies

# %%
data2 = pd.get_dummies(data.y,dtype=int)

# %%
data2.drop(columns="no",inplace=True)

# %%
data3 = pd.concat((data[['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome']],data2),axis=1)

# %%
data3
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
data3.rename(columns={"yes":"y"})
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
data3.insert(loc=0,column="client",value=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7436\3540342191.py in ?()
# ----> 1 data3.insert(loc=0,column="client",value=None)
#       2 data3
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ValueError: cannot insert client, already exists

# %%
data3
# Out:
#       client  age           job   marital  education default  balance housing  \
# 0       None   58    management   married   tertiary      no     2143     yes
# 1       None   44    technician    single  secondary      no       29     yes
# 2       None   33  entrepreneur   married  secondary      no        2     yes
# 3       None   47   blue-collar   married    unknown      no     1506     yes
# 4       None   33       unknown    single    unknown      no        1      no
# ...      ...  ...           ...       ...        ...     ...      ...     ...
# 45206   None   51    technician   married   tertiary      no      825      no
# 45207   None   71       retired  divorced    primary      no     1729      no
# 45208   None   72       retired   married  secondary      no     5715      no
# 45209   None   57   blue-collar   married  secondary      no      668      no
# 45210   None   37  entrepreneur   married  secondary      no     2971      no
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data3['client'] = le.fit_transform(data3['client'])

# %%
data3['client'] = pd.to_numeric(data3['client'])

# %%
data3['client'] = range (0 + len(data3))

# %%
data3
# Out:
#        client  age           job   marital  education default  balance  \
# 0           0   58    management   married   tertiary      no     2143
# 1           1   44    technician    single  secondary      no       29
# 2           2   33  entrepreneur   married  secondary      no        2
# 3           3   47   blue-collar   married    unknown      no     1506
# 4           4   33       unknown    single    unknown      no        1
# ...       ...  ...           ...       ...        ...     ...      ...
# 45206   45206   51    technician   married   tertiary      no      825
# 45207   45207   71       retired  divorced    primary      no     1729
# 45208   45208   72       retired   married  secondary      no     5715
# 45209   45209   57   blue-collar   married  secondary      no      668
# 45210   45210   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# # Defining the variable x(Independent) any y(Dependent)

# %%
x = data3[['age']].values

# %%
y = data.y

# %%
x1 = data3[['client']].values

# %%
y1 = data.y

# %% [markdown]
# # Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.7, test_size=0.3,random_state=0)

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1,y1,train_size=0.7, test_size=0.3,random_state=0)

# %% [markdown]
# # Applying Logistic regression from sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array(['no', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %%
model1 = LogisticRegression()

# %%
model1.fit(x1_train,y1_train)
# Out:
# LogisticRegression()

# %%
y1_pred = model1.predict(x1_test)

# %%
y1_pred
# Out:
# array(['no', 'no', 'no', ..., 'no', 'no', 'no'], dtype=object)

# %% [markdown]
# # Ploting the graph

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y1_pred)
plt.xlabel('tested data')
plt.ylabel('predicted data')
# Out:
# Text(0, 0.5, 'predicted data')
