# %% [markdown]
# # Installing Libraries

# %%
# !pip install ydata_profiling
# !pip install sweetviz

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import ydata_profiling as pp
import sweetviz as sv

# %%
data = pd.read_csv(r"C:\Excelr assignments\Assignment 5 Multi linear Regression\ToyotaCorolla.csv",encoding='latin1')

# %%
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
data1=data[["Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight","Price"]]

# %%
data1
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight  Price
# 0            23  46986   90  2000      3      5            210    1165  13500
# 1            23  72937   90  2000      3      5            210    1165  13750
# 2            24  41711   90  2000      3      5            210    1165  13950
# 3            26  48000   90  2000      3      5            210    1165  14950
# 4            30  38500   90  2000      3      5            210    1170  13750
# ...         ...    ...  ...   ...    ...    ...            ...     ...    ...
# 1431         69  20544   86  1300      3      5             69    1025   7500
# 1432         72  19000   86  1300      3      5             69    1015  10845
# 1433         71  17016   86  1300      3      5             69    1015   8500
# 1434         70  16916   86  1300      3      5             69    1015   7250
# 1435         76      1  110  1600      5      5             19    1114   6950
#
# [1436 rows x 9 columns]

# %% [markdown]
# # Performing Explorartory Data Analysis (EDA)

# %%
data1.tail(10)
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight  Price
# 1426         78  30964  110  1600      3      4             85    1080   9950
# 1427         71  29000   86  1300      3      5             69    1045   8950
# 1428         72  26000   86  1300      3      5             69    1015   8450
# 1429         78  24000   86  1300      5      5             85    1065   8950
# 1430         80  23000   86  1300      3      5             69    1015   8450
# 1431         69  20544   86  1300      3      5             69    1025   7500
# 1432         72  19000   86  1300      3      5             69    1015  10845
# 1433         71  17016   86  1300      3      5             69    1015   8500
# 1434         70  16916   86  1300      3      5             69    1015   7250
# 1435         76      1  110  1600      5      5             19    1114   6950

# %%
# defining the data type and structure
data1.dtypes
# Out:
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# Price            int64
# dtype: object

# %%
data1.shape
# Out:
# (1436, 9)

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
#Data type conversion
data1.describe()
# Out:
#          Age_08_04             KM           HP           cc        Doors  \
# count  1436.000000    1436.000000  1436.000000   1436.00000  1436.000000
# mean     55.947075   68533.259749   101.502089   1576.85585     4.033426
# std      18.599988   37506.448872    14.981080    424.38677     0.952677
# min       1.000000       1.000000    69.000000   1300.00000     2.000000
# 25%      44.000000   43000.000000    90.000000   1400.00000     3.000000
# 50%      61.000000   63389.500000   110.000000   1600.00000     4.000000
# 75%      70.000000   87020.750000   110.000000   1600.00000     5.000000
# max      80.000000  243000.000000   192.000000  16000.00000     5.000000
#
#              Gears  Quarterly_Tax      Weight         Price
# count  1436.000000    1436.000000  1436.00000   1436.000000
# mean      5.026462      87.122563  1072.45961  10730.824513
# std       0.188510      41.128611    52.64112   3626.964585
# min       3.000000      19.000000  1000.00000   4350.000000
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age_08_04      1436 non-null   int64
#  1   KM             1436 non-null   int64
#  2   HP             1436 non-null   int64
#  3   cc             1436 non-null   int64
#  4   Doors          1436 non-null   int64
#  5   Gears          1436 non-null   int64
#  6   Quarterly_Tax  1436 non-null   int64
#  7   Weight         1436 non-null   int64
#  8   Price          1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
#Checkin of any Duplicates
data1[data1.duplicated()].shape
# Out:
# (1, 9)

# %%
data1[data1.duplicated()]
# Out:
#      Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight  Price
# 113          8  13253  116  2000      5      5            234    1320  24950

# %%
# Outlier Detection
data1['Age_08_04'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Age_08_04')
# Out:
# <Axes: >

# %%
data1['KM'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('KM')
# Out:
# <Axes: >

# %%
data1['HP'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('HP')
# Out:
# <Axes: >

# %%
data1['cc'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('cc')
# Out:
# <Axes: >

# %%
data1['Doors'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Doors')
# Out:
# <Axes: >

# %%
data1['Gears'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Gears')
# Out:
# <Axes: >

# %%
data1['Quarterly_Tax'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Quarterly_Tax')
# Out:
# <Axes: >

# %%
data1['Weight'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Weight')
# Out:
# <Axes: >

# %%
data1['Price'].hist()
# Out:
# <Axes: >

# %%
data1.boxplot('Price')
# Out:
# <Axes: >

# %%
data1[data1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age_08_04, KM, HP, cc, Doors, Gears, Quarterly_Tax, Weight, Price]
# Index: []

# %%
data1.isnull().sum()
# Out:
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# Price            0
# dtype: int64

# %%
# Scatter plot and Correlation analysis
# seaborn visualisation
import seaborn as sns
sns.pairplot(data1)
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data1.corr()
# Out:
#                Age_08_04        KM        HP        cc     Doors     Gears  \
# Age_08_04       1.000000  0.505672 -0.156622 -0.098084 -0.148359 -0.005364
# KM              0.505672  1.000000 -0.333538  0.102683 -0.036197  0.015023
# HP             -0.156622 -0.333538  1.000000  0.035856  0.092424  0.209477
# cc             -0.098084  0.102683  0.035856  1.000000  0.079903  0.014629
# Doors          -0.148359 -0.036197  0.092424  0.079903  1.000000 -0.160141
# Gears          -0.005364  0.015023  0.209477  0.014629 -0.160141  1.000000
# Quarterly_Tax  -0.198431  0.278165 -0.298432  0.306996  0.109363 -0.005452
# Weight         -0.470253 -0.028598  0.089614  0.335637  0.302618  0.020613
# Price          -0.876590 -0.569960  0.314990  0.126389  0.185326  0.063104
#
#                Quarterly_Tax    Weight     Price
# Age_08_04          -0.198431 -0.470253 -0.876590
# KM                  0.278165 -0.028598 -0.569960
# HP                 -0.298432  0.089614  0.314990
# ...

# %%
data2 = data1.dropna()
data2
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight  Price
# 0            23  46986   90  2000      3      5            210    1165  13500
# 1            23  72937   90  2000      3      5            210    1165  13750
# 2            24  41711   90  2000      3      5            210    1165  13950
# 3            26  48000   90  2000      3      5            210    1165  14950
# 4            30  38500   90  2000      3      5            210    1170  13750
# ...         ...    ...  ...   ...    ...    ...            ...     ...    ...
# 1431         69  20544   86  1300      3      5             69    1025   7500
# 1432         72  19000   86  1300      3      5             69    1015  10845
# 1433         71  17016   86  1300      3      5             69    1015   8500
# 1434         70  16916   86  1300      3      5             69    1015   7250
# 1435         76      1  110  1600      5      5             19    1114   6950
#
# [1436 rows x 9 columns]

# %%
sns.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Creating dummies

# %%
data3 = pd.get_dummies(data2,columns=['Doors','Gears'],dtype=int)

# %%
data3
# Out:
#       Age_08_04     KM   HP    cc  Quarterly_Tax  Weight  Price  Doors_2  \
# 0            23  46986   90  2000            210    1165  13500        0
# 1            23  72937   90  2000            210    1165  13750        0
# 2            24  41711   90  2000            210    1165  13950        0
# 3            26  48000   90  2000            210    1165  14950        0
# 4            30  38500   90  2000            210    1170  13750        0
# ...         ...    ...  ...   ...            ...     ...    ...      ...
# 1431         69  20544   86  1300             69    1025   7500        0
# 1432         72  19000   86  1300             69    1015  10845        0
# 1433         71  17016   86  1300             69    1015   8500        0
# 1434         70  16916   86  1300             69    1015   7250        0
# 1435         76      1  110  1600             19    1114   6950        0
#
#       Doors_3  Doors_4  Doors_5  Gears_3  Gears_4  Gears_5  Gears_6
# ...

# %%
data3[data3.duplicated()]
# Out:
#      Age_08_04     KM   HP    cc  Quarterly_Tax  Weight  Price  Doors_2  \
# 113          8  13253  116  2000            234    1320  24950        0
#
#      Doors_3  Doors_4  Doors_5  Gears_3  Gears_4  Gears_5  Gears_6
# 113        0        0        1        0        0        1        0

# %% [markdown]
# # Defining the x and y  variables

# %%
x = data[["Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
y = data["Price"]

# %% [markdown]
# # Spliting the data set in train set and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train, y_test = train_test_split(x_test,y_test,train_size=0.7,test_size=0.3,random_state=0)

# %% [markdown]
# # Predicting the Test set values

# %%
from sklearn.linear_model import LinearRegression

# %%
ml = LinearRegression()

# %%
ml.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred = ml.predict(x_test)

# %%
y_pred
# Out:
# array([ 8692.29252524,  8687.64275426, 12826.02692105, 10407.02151144,
#         8065.35587859, 12689.42522092, 10141.1058365 , 13291.66716806,
#         8292.84418801, 11942.08697936,  9890.9842782 ,  7128.74216268,
#         8948.09027424, 19195.40307339, 10225.93863302, 14993.81132513,
#        11793.25037401, 16243.54495545, 12000.27383145, 11054.03874087,
#         7760.67426818, 15711.53695283, 16657.22087987, 12503.99824455,
#         7372.19168017,  8259.50662786, 13018.79517449, 21402.86680298,
#        11936.72794727,  7943.36084321,  8330.66270671, 30609.19783059,
#        13404.21441225,  9198.06410468,  8221.02669627, 10661.64448623,
#         8306.58627296, 13226.49259119, 12516.4111239 , 10994.07380368,
#         8263.76777838,  6617.56713534, 10828.14805871, 10368.03742452,
#        13305.15275373,  7104.47392018,  5855.42648773, 15916.03638929,
#         9812.98126679,  9399.03607577,  9192.53342223,  9353.76725105,
# ...

# %%
ml.coef_
# Out:
# array([-9.80054809e+01, -1.91408449e-02,  2.03966435e+01, -2.64242946e+00,
#        -1.92451538e+02,  1.34929452e+03, -1.86169900e+00,  3.65753583e+01])

# %%
ml.intercept_
# Out:
# -25440.10513221045

# %%
ml.score(x_test,y_test)
# Out:
# 0.8979190549330656

# %% [markdown]
# # Model for whole data set without training

# %%
ml1 = LinearRegression()

# %%
ml1.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred1 = ml.predict(x)

# %%
y_pred1
# Out:
# array([16345.70972417, 15848.98565827, 16348.67220014, ...,
#         8759.40762201,  8859.32718736, 11620.99464707])

# %%
ml1.coef_
# Out:
# array([-1.21658402e+02, -2.08171292e-02,  3.16809058e+01, -1.21100301e-01,
#        -1.61664095e+00,  5.94319936e+02,  3.94908076e+00,  1.69586318e+01])

# %%
ml1.intercept_
# Out:
# -5573.106357913728

# %% [markdown]
# # Plot the graph for model

# %%
import matplotlib.pyplot as mlt

# %%
mlt.scatter(y_test,y_pred)
mlt.xlabel('Actual Price')
mlt.ylabel('Predicted Price')
mlt.title('Actual Price vs.Predicted Price')
# Out:
# Text(0.5, 1.0, 'Actual Price vs.Predicted Price')

# %% [markdown]
# # Similarly plot for Whole data set

# %%
mlt.scatter(y,y_pred1)
mlt.xlabel('Actual Price')
mlt.ylabel('Predicted Price')
mlt.title('Actual Price vs.Predicted Price')
# Out:
# Text(0.5, 1.0, 'Actual Price vs.Predicted Price')

# %% [markdown]
# # Predicted Price , Actual Price and Difference in a dataframe

# %%
data4 = pd.DataFrame({'Predicted Price':y_pred, 'Actual Price':y_test, 'Difference':y_pred - y_test})

# %%
data4
# Out:
#       Predicted Price  Actual Price   Difference
# 1396      8692.292525          9800 -1107.707475
# 389       8687.642754          9450  -762.357246
# 339      12826.026921         11950   876.026921
# 832      10407.021511         10995  -587.978489
# 1271      8065.355879          7145   920.355879
# ...               ...           ...          ...
# 104      19444.938927         19450    -5.061073
# 290      12295.245161         12500  -204.754839
# 1360      8732.121772          9900 -1167.878228
# 961      10588.899761          8750  1838.899761
# 300      13132.933862         12750   382.933862
#
# [108 rows x 3 columns]

# %%
data5 = pd.DataFrame({'Predicted Price':y_pred1, 'Actual Price':y, 'Difference':y_pred1 - y})

# %%
data5
# Out:
#       Predicted Price  Actual Price   Difference
# 0        16345.709724         13500  2845.709724
# 1        15848.985658         13750  2098.985658
# 2        16348.672200         13950  2398.672200
# 3        16032.284465         14950  1082.284465
# 4        16004.977360         13750  2254.977360
# ...               ...           ...          ...
# 1431      9253.643266          7500  1753.643266
# 1432      8623.426705         10845 -2221.573295
# 1433      8759.407622          8500   259.407622
# 1434      8859.327187          7250  1609.327187
# 1435     11620.994647          6950  4670.994647
#
# [1436 rows x 3 columns]

# %%
Toyota_Corolla_report= pp.ProfileReport(data)
Toyota_Corolla_report.to_file(output_file='report.html')
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:354: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
Toyota_Corolla_report= sv.analyze(data)
Toyota_Corolla_report.show_html('report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
