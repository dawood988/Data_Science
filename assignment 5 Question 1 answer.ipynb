# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # Importing the data

# %%
data = pd.read_csv(r"C:\Users\Dawood MD\Downloads\50_Startups (1).csv")

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # Performing Explorartory Data Analysis (EDA)

# %%
data.tail(10)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 40   28754.33       118546.05        172795.67  California  78239.91
# 41   27892.92        84710.77        164470.71     Florida  77798.83
# 42   23640.93        96189.63        148001.11  California  71498.49
# 43   15505.73       127382.30         35534.17    New York  69758.98
# 44   22177.74       154806.14         28334.72  California  65200.33
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# defining the data type and structure
data.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data1 = data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data[data.duplicated()].shape
# Out:
# (0, 5)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#outliers detections
data['R&D Spend'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['R&D Spend'])
# Out:
# <Axes: >

# %%
data['Administration'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column='Administration')
# Out:
# <Axes: >

# %%
data['Marketing Spend'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['Marketing Spend'])
# Out:
# <Axes: >

# %%
data['State'].hist()
# Out:
# <Axes: >

# %%
data['State'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
data['Profit'].hist()
# Out:
# <Axes: >

# %%
data.boxplot(column=['Profit'])
# Out:
# <Axes: >

# %%
data1 = data.drop(columns=['State'])
data1.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
# Scatter plot and Correlation analysis
# seaborn visualisation
import seaborn as sns
sns.pairplot(data)
# Out:
# C:\Users\Dawood MD\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
data2 = pd.get_dummies(data,columns=['State'],dtype=float)
data2
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83               0.0
# 1   162597.70       151377.59        443898.53  191792.06               1.0
# 2   153441.51       101145.55        407934.54  191050.39               0.0
# 3   144372.41       118671.85        383199.62  182901.99               0.0
# 4   142107.34        91391.77        366168.42  166187.94               0.0
# 5   131876.90        99814.71        362861.36  156991.12               0.0
# 6   134615.46       147198.87        127716.82  156122.51               1.0
# 7   130298.13       145530.06        323876.68  155752.60               0.0
# 8   120542.52       148718.95        311613.29  152211.77               0.0
# 9   123334.88       108679.17        304981.62  149759.96               1.0
# 10  101913.08       110594.11        229160.95  146121.95               0.0
# ...

# %%
sns.heatmap(data2.corr(),annot=True)
# Out:
# <Axes: >

# %%
df= data2[['R&D Spend','Administration','Marketing Spend','State_California','State_Florida','State_New York','Profit']]

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State_California  \
# 0   165349.20       136897.80        471784.10               0.0
# 1   162597.70       151377.59        443898.53               1.0
# 2   153441.51       101145.55        407934.54               0.0
# 3   144372.41       118671.85        383199.62               0.0
# 4   142107.34        91391.77        366168.42               0.0
# 5   131876.90        99814.71        362861.36               0.0
# 6   134615.46       147198.87        127716.82               1.0
# 7   130298.13       145530.06        323876.68               0.0
# 8   120542.52       148718.95        311613.29               0.0
# 9   123334.88       108679.17        304981.62               1.0
# 10  101913.08       110594.11        229160.95               0.0
# 11  100671.96        91790.61        249744.55               1.0
# 12   93863.75       127320.38        249839.44               0.0
# ...

# %% [markdown]
# # Define x (independent) and y (dependent)

# %%
x =df[['R&D Spend','Administration','Marketing Spend','State_California','State_Florida','State_New York']]
y =df['Profit']

# %% [markdown]
# # Spliting the Data into Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=0)

# %% [markdown]
# # Predicting the values for test variables

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend  State_California  \
# 28   66051.52       182645.56        118148.20               0.0
# 11  100671.96        91790.61        249744.55               1.0
# 10  101913.08       110594.11        229160.95               0.0
# 41   27892.92        84710.77        164470.71               0.0
# 2   153441.51       101145.55        407934.54               0.0
# 27   72107.60       127864.55        353183.81               0.0
# 38   20229.59        65947.93        185265.10               0.0
# 31   61136.38       152701.92         88218.23               0.0
# 22   73994.56       122782.75        303319.26               0.0
# 4   142107.34        91391.77        366168.42               0.0
# 33   55493.95       103057.49        214634.81               0.0
# 35   46014.02        85047.44        205517.64               0.0
# 26   75328.87       144135.98        134050.07               0.0
# ...

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# Name: Profit, dtype: float64

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 98668.86442605, 148149.36577412, 138124.44723034,  79121.91405024,
#        181287.39517909, 109374.85408984,  75834.8394114 ,  99994.7891373 ,
#        111457.23768425, 173495.1359409 ,  99548.63507211,  94995.95736146,
#        111850.30941312,  92822.83422588, 128019.16100391])

# %%
c = lr.intercept_
c
# Out:
# 72544.15309233766

# %%
m = lr.coef_
m
# Out:
# array([ 8.58116741e-01, -1.41075445e-01, -1.33544350e-02,  5.50151692e+03,
#        -3.21059769e+03, -2.29091923e+03])

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
r2_score = lr.score(x_test,y_test)
r2_score
# Out:
# 0.9735454212789452

# %% [markdown]
# # similarly for whole set we can predict as

# %%
lr1 = LinearRegression()

# %%
lr1.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred1 = lr1.predict(x)
y_pred1
# Out:
# array([192390.57136321, 189071.32010494, 182276.18673283, 173584.97618975,
#        172277.13381666, 163473.8071184 , 158099.29278417, 160155.64464939,
#        151634.74332631, 154829.66252708, 135664.64259063, 135528.60078159,
#        129282.91780691, 127431.24898632, 149694.3827755 , 146143.63551378,
#        116854.0745287 , 130085.40993359, 129149.72574273, 115594.18840731,
#        116570.73444001, 117201.50508975, 114833.30513844, 110123.79610587,
#        113294.37345154, 102200.26891867, 110765.3011688 , 114279.80403012,
#        101818.58738693, 101721.04202941,  99629.0105373 ,  97617.29632021,
#         98988.23660304,  98061.35894838,  88974.70416296,  90420.00960609,
#         75423.09286561,  89577.70222194,  69606.52160902,  83684.9760399 ,
#         74762.74617648,  74956.31104907,  70575.99371382,  60100.2682187 ,
#         64585.14721293,  47588.36470994,  56272.99268497,  46468.23200485,
#         49123.07308284,  48185.0387926 ])

# %%
c1 = lr.intercept_
c1
# Out:
# 72544.15309233766

# %%
m1 = lr.coef_
m1
# Out:
# array([ 8.58116741e-01, -1.41075445e-01, -1.33544350e-02,  5.50151692e+03,
#        -3.21059769e+03, -2.29091923e+03])

# %%
r2_score1 = lr.score(x,y)
r2_score1
# Out:
# 0.9168502452819071

# %% [markdown]
# # Ploting the graph for test set and whole data set

# %%
plt.pyplot.scatter(y_test,y_pred)
plt.pyplot.xlabel('Profit')
plt.pyplot.ylabel('Predicted Profit')
plt.pyplot.title('Profit vs. Predicted Profit')
# Out:
# Text(0.5, 1.0, 'Profit vs. Predicted Profit')

# %%
plt.pyplot.scatter(y,y_pred1)
plt.pyplot.xlabel('Profit')
plt.pyplot.ylabel('Predicted Profit')
plt.pyplot.title('Profit vs. Predicted Profit')
# Out:
# Text(0.5, 1.0, 'Profit vs. Predicted Profit')

# %%
data5 = pd.DataFrame({'Predicted Profit':y_pred, 'Profit':y_test, 'Difference':y_pred - y_test })
data5
# Out:
#     Predicted Profit     Profit   Difference
# 28      98668.864426  103282.38 -4613.515574
# 11     148149.365774  144259.40  3889.965774
# 10     138124.447230  146121.95 -7997.502770
# 41      79121.914050   77798.83  1323.084050
# 2      181287.395179  191050.39 -9762.994821
# 27     109374.854090  105008.31  4366.544090
# 38      75834.839411   81229.06 -5394.220589
# 31      99994.789137   97483.56  2511.229137
# 22     111457.237684  110352.25  1104.987684
# 4      173495.135941  166187.94  7307.195941
# 33      99548.635072   96778.92  2769.715072
# 35      94995.957361   96479.51 -1483.552639
# 26     111850.309413  105733.54  6116.769413
# 34      92822.834226   96712.80 -3889.965774
# 18     128019.161004  124266.90  3752.261004

# %%
data6 = pd.DataFrame({'Predicted Profit':y_pred1, 'Profit':y, 'Difference':y_pred1 - y})
data6
# Out:
#     Predicted Profit     Profit    Difference
# 0      192390.571363  192261.83    128.741363
# 1      189071.320105  191792.06  -2720.739895
# 2      182276.186733  191050.39  -8774.203267
# 3      173584.976190  182901.99  -9317.013810
# 4      172277.133817  166187.94   6089.193817
# 5      163473.807118  156991.12   6482.687118
# 6      158099.292784  156122.51   1976.782784
# 7      160155.644649  155752.60   4403.044649
# 8      151634.743326  152211.77   -577.026674
# 9      154829.662527  149759.96   5069.702527
# 10     135664.642591  146121.95 -10457.307409
# 11     135528.600782  144259.40  -8730.799218
# 12     129282.917807  141585.52 -12302.602193
# 13     127431.248986  134307.35  -6876.101014
# 14     149694.382776  132602.65  17091.732776
# 15     146143.635514  129917.04  16226.595514
# 16     116854.074529  126992.93 -10138.855471
# 17     130085.409934  125370.37   4715.039934
# 18     129149.725743  124266.90   4882.825743
# ...

# %%
# !pip install tabulate

# %%
from tabulate import tabulate

# %%
data7 = [[0.9735],
        [0.9168]]

col_name = ['R2_square'] 
print(tabulate(data7, headers=col_name,tablefmt='grid',showindex='always',disable_numparse=True))
# Out:
# +----+-------------+
# |    | R2_square   |
# +====+=============+
# | 0  | 0.9735      |
# +----+-------------+
# | 1  | 0.9168      |
# +----+-------------+
