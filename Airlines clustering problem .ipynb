# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import AgglomerativeClustering 
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
import seaborn as sn

# %%
air_lines = pd.read_csv(r"C:\Excelr assignments\Assignment 7 Clustering\EastWestAirlines.csv")

# %%
air_lines.head(20)
# Out:
#     ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     1    28143           0          1          1          1          174
# 1     2    19244           0          1          1          1          215
# 2     3    41354           0          1          1          1         4123
# 3     4    14776           0          1          1          1          500
# 4     5    97752           0          4          1          1        43300
# 5     6    16420           0          1          1          1            0
# 6     7    84914           0          3          1          1        27482
# 7     8    20856           0          1          1          1         5250
# 8     9   443003           0          3          2          1         1753
# 9    10   104860           0          3          1          1        28426
# 10   11    40091           0          2          1          1         7278
# ...

# %%
air_lines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air_lines.describe
# Out:
# <bound method NDFrame.describe of        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # Normalization of the data

# %%
def norm_func (i):
    x = (i - i.min())/(i.max() - i.min())
    return x 
df_norm = norm_func (air_lines.iloc[:,1:])

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # Create a dendrogram of whole set

# %%
dendrogram = hierarchy.dendrogram(hierarchy.linkage(df_norm, method='single'))

# %%
dendrogram
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [65.0, 65.0, 80.0, 80.0],
#   [55.0, 55.0, 72.5, 72.5],
#   [45.0, 45.0, 63.75, 63.75],
#   [105.0, 105.0, 115.0, 115.0],
#   [95.0, 95.0, 110.0, 110.0],
#   [54.375, 54.375, 102.5, 102.5],
#   [35.0, 35.0, 78.4375, 78.4375],
#   [165.0, 165.0, 175.0, 175.0],
#   [185.0, 185.0, 195.0, 195.0],
#   [170.0, 170.0, 190.0, 190.0],
#   [155.0, 155.0, 180.0, 180.0],
#   [205.0, 205.0, 215.0, 215.0],
#   [245.0, 245.0, 255.0, 255.0],
#   [265.0, 265.0, 275.0, 275.0],
#   [250.0, 250.0, 270.0, 270.0],
#   [235.0, 235.0, 260.0, 260.0],
#   [225.0, 225.0, 247.5, 247.5],
#   [210.0, 210.0, 236.25, 236.25],
#   [167.5, 167.5, 223.125, 223.125],
#   [145.0, 145.0, 195.3125, 195.3125],
#   [135.0, 135.0, 170.15625, 170.15625],
#   [125.0, 125.0, 152.578125, 152.578125],
#   [375.0, 375.0, 385.0, 385.0],
#   [365.0, 365.0, 380.0, 380.0],
#   [455.0, 455.0, 465.0, 465.0],
#   [575.0, 575.0, 585.0, 585.0],
# ...

# %% [markdown]
# # Creating the clusters

# %%
hc = AgglomerativeClustering(n_clusters=5,metric='euclidean',linkage='single')

# %%
y_hc = hc.fit_predict(df_norm)
cluster = pd.DataFrame(y_hc,columns=['cluster'])

# %%
df_norm['h_clusteriod'] = cluster

# %%
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   float64
#  1   Qual_miles         3999 non-null   float64
#  2   cc1_miles          3999 non-null   float64
#  3   cc2_miles          3999 non-null   float64
#  4   cc3_miles          3999 non-null   float64
#  5   Bonus_miles        3999 non-null   float64
#  6   Bonus_trans        3999 non-null   float64
#  7   Flight_miles_12mo  3999 non-null   float64
#  8   Flight_trans_12    3999 non-null   float64
#  9   Days_since_enroll  3999 non-null   float64
#  10  Award?             3999 non-null   float64
#  11  h_clusteriod       3999 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 375.0 KB

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # K-Mean clustering

# %%
from sklearn.cluster import KMeans

# %%
air_lines.head(50)
# Out:
#     ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     1    28143           0          1          1          1          174
# 1     2    19244           0          1          1          1          215
# 2     3    41354           0          1          1          1         4123
# 3     4    14776           0          1          1          1          500
# 4     5    97752           0          4          1          1        43300
# 5     6    16420           0          1          1          1            0
# 6     7    84914           0          3          1          1        27482
# 7     8    20856           0          1          1          1         5250
# 8     9   443003           0          3          2          1         1753
# 9    10   104860           0          3          1          1        28426
# 10   11    40091           0          2          1          1         7278
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(air_lines.iloc[:,1:])

# %%
df_norm1= pd.DataFrame(scaled)

# %%
df_norm1
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10
# ...

# %%
wcss = []
for i in range (1,20):
    kmeans = KMeans(n_clusters=i,random_state=20,n_init=20)
    kmeans.fit(scaled)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,20),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# # Build the cluster algorithm

# %%
cluster_kmeans = KMeans(n_clusters=5,random_state=20,n_init=10)
cluster_kmeans.fit(scaled)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=20)

# %%
cluster_kmeans.labels_
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %% [markdown]
# # Assign the cluster to the data set

# %%
df_norm['clusteriod_kmean'] = cluster_kmeans.labels_

# %%
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_norm.groupby('clusteriod_kmean').agg(['mean']).reset_index()
# Out:
#   clusteriod_kmean   Balance Qual_miles cc1_miles cc2_miles cc3_miles  \
#                         mean       mean      mean      mean      mean
# 0                0  0.068674   0.014675  0.675039  0.000000  0.000392
# 1                1  0.025717   0.008556  0.056651  0.000000  0.000100
# 2                2  0.040401   0.002086  0.034884  0.674419  0.000000
# 3                3  0.112983   0.072565  0.296474  0.000000  0.000000
# 4                4  0.080982   0.007069  0.616667  0.000000  0.766667
#
#   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll  \
#          mean        mean              mean            mean              mean
# 0    0.148718    0.217909          0.011317        0.019431          0.589428
# 1    0.017486    0.079288          0.006504        0.011730          0.444579
# 2    0.055710    0.203894          0.018906        0.041685          0.478289
# 3    0.121174    0.314848          0.178784        0.302492          0.568237
# ...

# %% [markdown]
# # DBSCAN Method

# %%
#importing the necessary libraries
from sklearn.cluster import DBSCAN

# %%
array = df_norm1.values
array
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
dbscan = DBSCAN(eps=0.9,min_samples=10)
dbscan.fit(array)
# Out:
# DBSCAN(eps=0.9, min_samples=10)

# %%
# noise samples are given the labels '-1'
dbscan.labels_.view()
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
dbscan.get_params
# Out:
# <bound method BaseEstimator.get_params of DBSCAN(eps=0.9, min_samples=10)>

# %%
clustering_dbscan = pd.DataFrame(dbscan.labels_,columns=['dbscan_Cluster'])

# %%
clustering_dbscan
# Out:
#       dbscan_Cluster
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                 -1
# ...              ...
# 3994               1
# 3995               1
# 3996               1
# 3997               0
# 3998               0
#
# [3999 rows x 1 columns]

# %%
df3 = pd.concat([df_norm,clustering_dbscan],axis=1)

# %%
df3
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
